# %%
# %git clone https://github.com/ultralytics/yolov5  # clone repo
# %pip install -U -r yolov5/requirements.txt  # install dependencies
# Out:
# Clonando en 'yolov5'...
# remote: Enumerating objects: 12194, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 12194 (delta 33), reused 24 (delta 5), pack-reused 12124
# Recibiendo objetos: 100% (12194/12194), 12.64 MiB | 10.48 MiB/s, listo.
# Resolviendo deltas: 100% (8383/8383), listo.
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.5.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 4.1 MB/s eta 0:00:01
# Collecting numpy>=1.18.5
#   Downloading numpy-1.23.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 10.5 MB/s eta 0:00:01
# Collecting opencv-python>=4.1.1
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      |████████████████████████████████| 60.9 MB 10.7 MB/s eta 0:00:01
# Collecting Pillow>=7.1.2
#   Downloading Pillow-9.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 12.5 MB/s eta 0:00:01
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      |████████████████████████████████| 701 kB 11.7 MB/s eta 0:00:01
# Collecting requests>=2.23.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 2.6 MB/s  eta 0:00:01
# Collecting scipy>=1.4.1
#   Downloading scipy-1.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.4 MB)
#      |████████████████████████████████| 43.4 MB 12.3 MB/s eta 0:00:01     |███████████████▌                | 21.0 MB 12.2 MB/s eta 0:00:02
# Collecting torch>=1.7.0
#   Downloading torch-1.12.1-cp38-cp38-manylinux1_x86_64.whl (776.3 MB)
#      |████████████████████████████████| 776.3 MB 3.8 kB/s  eta 0:00:01     |█████▎                          | 128.2 MB 12.2 MB/s eta 0:00:54     |███████                         | 170.3 MB 12.3 MB/s eta 0:00:50     |████████████████████▌           | 497.1 MB 10.4 MB/s eta 0:00:27     |████████████████████▋           | 499.5 MB 10.4 MB/s eta 0:00:27     |██████████████████████████████▍ | 737.9 MB 12.2 MB/s eta 0:00:04     |██████████████████████████████▌ | 740.9 MB 12.2 MB/s eta 0:00:03
# Collecting torchvision>=0.8.1
#   Downloading torchvision-0.13.1-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 12.1 MB/s eta 0:00:017 MB 12.1 MB/s eta 0:00:01
# Collecting tqdm>=4.64.0
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 8.1 MB/s  eta 0:00:01
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 12.1 MB/s eta 0:00:01
# Collecting pandas>=1.1.4
#   Downloading pandas-1.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 309 kB/s  eta 0:00:01
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.12.0-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 12.0 MB/s eta 0:00:01
# Collecting ipython
#   Downloading ipython-8.5.0-py3-none-any.whl (752 kB)
#      |████████████████████████████████| 752 kB 12.7 MB/s eta 0:00:01
# Collecting psutil
#   Downloading psutil-5.9.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (284 kB)
#      |████████████████████████████████| 284 kB 12.5 MB/s eta 0:00:01
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2207130030-py3-none-any.whl (15 kB)
# Requirement already satisfied, skipping upgrade: fonttools>=4.22.0 in /home/fundamentia/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (4.33.3)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in /home/fundamentia/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /home/fundamentia/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (21.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in /home/fundamentia/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/fundamentia/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/fundamentia/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 10)) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 10)) (2019.11.28)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in /home/fundamentia/.local/lib/python3.8/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 10)) (1.24.3)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied, skipping upgrade: typing-extensions in /home/fundamentia/.local/lib/python3.8/site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 12)) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: absl-py>=0.4 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.15.0)
# Requirement already satisfied, skipping upgrade: tensorboard-data-server<0.7.0,>=0.6.0 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.6.1)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (45.2.0)
# Requirement already satisfied, skipping upgrade: google-auth<3,>=1.6.3 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.35.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=1.0.1 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (2.1.2)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.4.6)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (3.3.7)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.8.1)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 13.1 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: grpcio>=1.24.3 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.32.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /home/fundamentia/.local/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.37.1)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in /home/fundamentia/.local/lib/python3.8/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 23)) (2022.1)
# Requirement already satisfied, skipping upgrade: decorator in /usr/lib/python3/dist-packages (from ipython->-r yolov5/requirements.txt (line 38)) (4.4.2)
# Collecting traitlets>=5
#   Using cached traitlets-5.3.0-py3-none-any.whl (106 kB)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<3.1.0,>3.0.1 in /home/fundamentia/.local/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 38)) (3.0.29)
# Collecting stack-data
#   Downloading stack_data-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied, skipping upgrade: backcall in /usr/lib/python3/dist-packages (from ipython->-r yolov5/requirements.txt (line 38)) (0.1.0)
# Requirement already satisfied, skipping upgrade: pexpect>4.3; sys_platform != "win32" in /usr/lib/python3/dist-packages (from ipython->-r yolov5/requirements.txt (line 38)) (4.6.0)
# Collecting jedi>=0.16
#   Using cached jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
# Collecting pygments>=2.4.0
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 12.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pickleshare in /usr/lib/python3/dist-packages (from ipython->-r yolov5/requirements.txt (line 38)) (0.7.5)
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/fundamentia/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /home/fundamentia/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (4.2.4)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /home/fundamentia/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (4.8)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /home/fundamentia/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.2.8)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /home/fundamentia/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=4.4; python_version < "3.10" in /home/fundamentia/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (4.11.3)
# Requirement already satisfied, skipping upgrade: wcwidth in /usr/lib/python3/dist-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->-r yolov5/requirements.txt (line 38)) (0.1.8)
# Collecting executing
#   Downloading executing-1.0.0-py2.py3-none-any.whl (16 kB)
# Collecting asttokens
#   Downloading asttokens-2.0.8-py2.py3-none-any.whl (23 kB)
# Collecting pure-eval
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting parso<0.9.0,>=0.8.0
#   Using cached parso-0.8.3-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /home/fundamentia/.local/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (3.1.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.0.0)
# ERROR: tensorflow 2.4.0 has requirement numpy~=1.19.2, but you'll have numpy 1.23.2 which is incompatible.
# Installing collected packages: Pillow, numpy, matplotlib, opencv-python, PyYAML, charset-normalizer, requests, scipy, torch, torchvision, tqdm, protobuf, tensorboard, pandas, seaborn, traitlets, executing, asttokens, pure-eval, stack-data, parso, jedi, pygments, matplotlib-inline, ipython, psutil, thop
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.1.0
#     Uninstalling Pillow-9.1.0:
#       Successfully uninstalled Pillow-9.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.2
#     Uninstalling matplotlib-3.5.2:
#       Successfully uninstalled matplotlib-3.5.2
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.5.5.64
#     Uninstalling opencv-python-4.5.5.64:
#       Successfully uninstalled opencv-python-4.5.5.64
#   Attempting uninstall: requests
#     Found existing installation: requests 2.21.0
#     Uninstalling requests-2.21.0:
#       Successfully uninstalled requests-2.21.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.0
#     Uninstalling tensorboard-2.9.0:
#       Successfully uninstalled tensorboard-2.9.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.2
#     Uninstalling pandas-1.4.2:
#       Successfully uninstalled pandas-1.4.2
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# Successfully installed Pillow-9.2.0 PyYAML-6.0 asttokens-2.0.8 charset-normalizer-2.1.1 executing-1.0.0 ipython-8.5.0 jedi-0.18.1 matplotlib-3.5.3 matplotlib-inline-0.1.6 numpy-1.23.2 opencv-python-4.6.0.66 pandas-1.4.4 parso-0.8.3 protobuf-3.19.4 psutil-5.9.2 pure-eval-0.2.2 pygments-2.13.0 requests-2.28.1 scipy-1.9.1 seaborn-0.12.0 stack-data-0.5.0 tensorboard-2.10.0 thop-0.1.1.post2207130030 torch-1.12.1 torchvision-0.13.1 tqdm-4.64.1 traitlets-5.3.0
